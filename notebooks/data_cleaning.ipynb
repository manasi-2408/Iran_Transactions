# %% [markdown]
# ## Importing the libraries

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Loading the data

# %%
data = pd.read_csv(r'../data/trx-10k.csv')

# %%
data.head()
# Out:
#     status                 time card_type     city     amount  id
# 0  success  2025-09-07 10:48:00      Visa   Tehran  1427657.0  98
# 1  success  2025-09-20 13:10:00  MastCard   Tehran  1578078.0  52
# 2     fail  2025-09-29 03:27:00      Visa  Tehran    250000.0  20
# 3  success  2025-09-15 13:13:00  Discover  Isfahan        0.0  40
# 4  success  2025-09-11 11:11:00      Visa   Tehran  1782689.0  59

# %% [markdown]
# ## Extracting some information

# %%
data.isna().sum()
# Out:
# status         0
# time           0
# card_type    311
# city         116
# amount         0
# id             0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   status     10000 non-null  object
#  1   time       10000 non-null  object
#  2   card_type  9689 non-null   object
#  3   city       9884 non-null   object
#  4   amount     10000 non-null  float64
#  5   id         10000 non-null  int64
# dtypes: float64(1), int64(1), object(4)
# memory usage: 468.9+ KB

# %%
data.shape
# Out:
# (10000, 6)

# %%
data.size
# Out:
# 60000

# %%
data.describe(include='all')
# Out:
#        status                 time card_type    city        amount  \
# count   10000                10000      9689    9884  1.000000e+04
# unique      6                 1724        10      14           NaN
# top      fail  2025-09-29 11:11:00      Visa  Tehran           NaN
# freq     3964                   25      2358    2063           NaN
# mean      NaN                  NaN       NaN     NaN  2.954735e+08
# std       NaN                  NaN       NaN     NaN  1.692035e+09
# min       NaN                  NaN       NaN     NaN -9.999990e+05
# 25%       NaN                  NaN       NaN     NaN  1.005000e+02
# 50%       NaN                  NaN       NaN     NaN  3.436790e+05
# 75%       NaN                  NaN       NaN     NaN  9.144650e+05
# max       NaN                  NaN       NaN     NaN  1.000000e+10
#
#                   id
# count   10000.000000
# unique           NaN
# top              NaN
# freq             NaN
# mean       50.061200
# std        28.870875
# min         1.000000
# 25%        25.000000
# 50%        50.000000
# 75%        74.000000
# max       100.000000

# %% [markdown]
# ## Cleaning of data

# %%
data.head()
# Out:
#     status                 time card_type     city     amount  id
# 0  success  2025-09-07 10:48:00      Visa   Tehran  1427657.0  98
# 1  success  2025-09-20 13:10:00  MastCard   Tehran  1578078.0  52
# 2     fail  2025-09-29 03:27:00      Visa  Tehran    250000.0  20
# 3  success  2025-09-15 13:13:00  Discover  Isfahan        0.0  40
# 4  success  2025-09-11 11:11:00      Visa   Tehran  1782689.0  59

# %% [markdown]
# ## Renaming all the columns

# %%
data.rename(columns={
    'status':'Status',
    'time':'Time',
    'card_type':'Card_Type',
    'city':'City',
    'amount':'Amount',
    'id':'ID'
}, inplace = True)

# %%
data.head()
# Out:
#     Status                 Time Card_Type     City     Amount  ID
# 0  success  2025-09-07 10:48:00      Visa   Tehran  1427657.0  98
# 1  success  2025-09-20 13:10:00  MastCard   Tehran  1578078.0  52
# 2     fail  2025-09-29 03:27:00      Visa  Tehran    250000.0  20
# 3  success  2025-09-15 13:13:00  Discover  Isfahan        0.0  40
# 4  success  2025-09-11 11:11:00      Visa   Tehran  1782689.0  59

# %% [markdown]
# ## Unique values fixing

# %%
#success and fail
data['Status'].unique()

data['Status'] = data['Status'].replace({
    'success': 'Success',
    'succeed': 'Success',
    'Success': 'Success',
    'fail': 'Fail',
    'failed': 'Fail',
    'FAIL': 'Fail'
})

# %%
#visa, nan, mastercard, discover, amex
data['Card_Type'].unique()

data['Card_Type'] = data['Card_Type'].replace({
    'MastCard':'Master Card',
    'Master-Card':'Master Card',
    'visa':'Visa',
    'Vsa':'Visa',
    'VISA':'Visa',
    'MasterCard':'Master Card'
})

# %%
#tehran, isfahan, tabriz, shiraz, karaj, ahvaz, qom, mashhad, nan
data['City'].unique()

data['City'] = data['City'].replace({
    'Tehran ':'Tehran',
    'TEHRAN':'Tehran',
    'karaj':'Karaj',
    'THR':'Tehran',
    'tehr@n':'Tehran',
    'ThRan':'Tehran'
})

# %% [markdown]
# ## Making a new column
# Amount is in negative. It doesn't mean the data is broken or bad it means the payment might have been refunded.

# %%
data["Amount_Type"] = np.select(
    [
        data["Amount"] > 0,
        data["Amount"] < 0,
        data["Amount"] == 0
    ],
    [
        "Payment",
        "Refund",
        "Zero_Amount"
    ],
    default="Unknown"
)

# %% [markdown]
# ## Filling null values

# %%
data['Card_Type'] = data['Card_Type'].fillna('Unknown')
data['City'] = data['City'].fillna('Unknown')

# %% [markdown]
# ## Extracting hour

# %%
data['Time'] = pd.to_datetime(data['Time'])

# %%
data['Hour'] = data['Time'].dt.hour

# %%
data.head(10)
# Out:
#     Status                Time    Card_Type     City     Amount  ID  \
# 0  Success 2025-09-07 10:48:00         Visa   Tehran  1427657.0  98
# 1  Success 2025-09-20 13:10:00  Master Card   Tehran  1578078.0  52
# 2     Fail 2025-09-29 03:27:00         Visa   Tehran   250000.0  20
# 3  Success 2025-09-15 13:13:00     Discover  Isfahan        0.0  40
# 4  Success 2025-09-11 11:11:00         Visa   Tehran  1782689.0  59
# 5     Fail 2025-09-08 21:21:00     Discover   Tehran  1050805.0  77
# 6  Success 2025-09-29 22:27:00         Visa   Tabriz  1387769.0  14
# 7     Fail 2025-09-21 03:00:00  Master Card   Tehran  1502601.0  44
# 8  Success 2025-09-07 12:12:00     Discover  Isfahan  -999999.0  87
# 9     Fail 2025-09-26 07:32:00         Visa   Tehran        0.0  82
#
#    Amount_Type  Hour
# 0      Payment    10
# 1      Payment    13
# 2      Payment     3
# 3  Zero_Amount    13
# 4      Payment    11
# 5      Payment    21
# 6      Payment    22
# 7      Payment     3
# 8       Refund    12
# 9  Zero_Amount     7

# %% [markdown]
# ## Saving the data

# %%
data.to_csv(r'iran_transactions.csv', index=False)
